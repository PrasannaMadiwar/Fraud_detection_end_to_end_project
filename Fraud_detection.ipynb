# %% [markdown]
# <a href="https://colab.research.google.com/github/PrasannaMadiwar/Fraud_detection_end_to_end_project/blob/main/Fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("/content/creditcard_2023.csv")

# %%
df.iloc[364665]
# Out:
# V1            0.977438
# V2            0.297915
# V3           -0.661028
# V4            1.021690
# V5            0.740218
# V6           -0.311576
# V7            0.091833
# V8           -0.076835
# V9           -0.710415
# V10          -0.298937
# V11           0.685467
# V12          -0.561437
# V13          -0.375868
# V14          -1.085946
# V15          -1.400402
# V16           0.229002
# V17           0.058037
# V18           0.520616
# V19          -1.317342
# V20           0.078578
# V21          -0.049695
# V22          -0.637215
# V23          -0.114800
# V24          -1.392290
# V25           0.540989
# V26           0.206059
# V27           0.360926
# V28           0.550727
# Amount    14773.520000
# Class         1.000000
# Name: 364665, dtype: float64

# %%
df.sample(10)
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 303901 -0.565299  0.946572 -1.300122  1.321687 -1.110697 -0.940942 -1.493237
# 67258  -0.233892 -0.449063  1.178229 -0.099334  0.387604 -0.320917  0.288342
# 445442 -0.213011  0.340733 -0.722106  0.322724 -0.578699 -0.702045 -0.375774
# 158179 -0.538075 -1.070827  1.562216  0.986519  2.825000 -0.344069  0.013371
# 144331  0.921488 -0.473574  1.015407 -0.063025  0.049025  0.617668  0.308854
# 62674   1.131113 -0.916136  1.003795 -1.291580 -0.365293 -0.112933  0.095949
# 364665  0.977438  0.297915 -0.661028  1.021690  0.740218 -0.311576  0.091833
# 145920  1.789463 -0.380794 -0.064412 -0.439016  0.453104 -0.050672  0.528166
# 526449 -2.268195  2.679644 -2.203459  1.219856 -2.708124 -2.551142 -2.125155
# 333115 -0.745442  0.302512 -0.619345  0.002906 -0.128097 -0.568846 -0.324936
#
#               V8        V9       V10  ...       V21       V22       V23  \
# ...

# %%
df.shape
# Out:
# (172524, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172524 entries, 0 to 172523
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      172524 non-null  int64
#  1   V1      172524 non-null  float64
#  2   V2      172524 non-null  float64
#  3   V3      172524 non-null  float64
#  4   V4      172524 non-null  float64
#  5   V5      172524 non-null  float64
#  6   V6      172524 non-null  float64
#  7   V7      172524 non-null  float64
#  8   V8      172524 non-null  float64
#  9   V9      172524 non-null  float64
#  10  V10     172524 non-null  float64
#  11  V11     172524 non-null  float64
#  12  V12     172524 non-null  float64
#  13  V13     172524 non-null  float64
#  14  V14     172524 non-null  float64
#  15  V15     172524 non-null  float64
#  16  V16     172524 non-null  float64
#  17  V17     172524 non-null  float64
#  18  V18     172524 non-null  float64
#  19  V19     172524 non-null  float64
# ...

# %%
df.describe()
# Out:
#                   id             V1             V2             V3  \
# count  172524.000000  172524.000000  172524.000000  172524.000000
# mean    86261.500000       0.376729      -0.475233       0.909102
# std     49803.533258       0.703560       0.675421       0.692387
# min         0.000000      -3.495584     -49.966572      -2.631176
# 25%     43130.750000      -0.157615      -0.638758       0.440119
# 50%     86261.500000       0.123833      -0.408397       0.818297
# 75%    129392.250000       0.980590      -0.188071       1.311386
# max    172523.000000       2.211189       4.361865      14.125834
#
#                   V4             V5             V6             V7  \
# count  172524.000000  172524.000000  172524.000000  172524.000000
# mean       -0.675148       0.265766       0.468620       0.457297
# std         0.653292       0.634049       0.707855       0.506273
# min        -4.795050      -5.182978     -21.111108      -4.351839
# ...

# %%
df.isna().sum()
# Out:
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.drop('id',axis=1,inplace=True)

# %%
corr = df.corr()

# %%
plt.figure(figsize=(30,20))
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1    284315
# Name: count, dtype: int64

# %%
for i in df.columns:
  plt.figure(figsize=(10,5))
  sns.boxplot(df[i])
  plt.show()

# %%
for i in df.columns:
  for j in df.columns:
    if i != j:
      plt.figure(figsize=(10,5))
      sns.scatterplot(x=df[i], y=df[j], hue=df['Class'])
      plt.title(f'{i} vs {j}')
      plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop('Class', axis=1)
y = df['Class']

# %%
X_train,X_test,y_train,y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
SS = StandardScaler()
SS.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_s = SS.transform(X_train)

# %%
X_test_s = SS.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble  import RandomForestClassifier
from sklearn.svm import SVC

# %%
lr = LogisticRegression(class_weight='balanced')
lr.fit(X_train_s, y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
rt = RandomForestClassifier(class_weight='balanced')
rt.fit(X_train_s, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
from sklearn.metrics import recall_score , f1_score, classification_report

# %%
y_pred = rt.predict(X_test_s)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56750
#            1       1.00      1.00      1.00     56976
#
#     accuracy                           1.00    113726
#    macro avg       1.00      1.00      1.00    113726
# weighted avg       1.00      1.00      1.00    113726

# %%
y_pred = lr.predict(X_test_s)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97     56750
#            1       0.98      0.95      0.96     56976
#
#     accuracy                           0.97    113726
#    macro avg       0.97      0.97      0.97    113726
# weighted avg       0.97      0.97      0.97    113726

# %%
y_pred = xg.predict(X_test_s)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56750
#            1       1.00      1.00      1.00     56976
#
#     accuracy                           1.00    113726
#    macro avg       1.00      1.00      1.00    113726
# weighted avg       1.00      1.00      1.00    113726

# %%
from sklearn.metrics import accuracy_score

# Predict on training data
y_train_pred = rt.predict(X_train_s)
print("Train Accuracy:", accuracy_score(y_train, y_train_pred))

# Predict on test data
y_test_pred = rt.predict(X_test_s)
print("Test Accuracy:", accuracy_score(y_test, y_test_pred))
# Out:
# Train Accuracy: 1.0
# Test Accuracy: 0.9998593109755025

# %%
from sklearn.metrics import accuracy_score

# Predict on training data
y_train_pred = lr.predict(X_train_s)
print("Train Accuracy:", accuracy_score(y_train, y_train_pred))

# Predict on test data
y_test_pred = lr.predict(X_test_s)
print("Test Accuracy:", accuracy_score(y_test, y_test_pred))
# Out:
# Train Accuracy: 0.9649552433040818
# Test Accuracy: 0.9652322248210612

# %%
from sklearn.metrics import accuracy_score

# Predict on training data
y_train_pred = xg.predict(X_train_s)
print("Train Accuracy:", accuracy_score(y_train, y_train_pred))

# Predict on test data
y_test_pred = xg.predict(X_test_s)
print("Test Accuracy:", accuracy_score(y_test, y_test_pred))
# Out:
# Train Accuracy: 0.9999934052019767
# Test Accuracy: 0.9997274150150361

# %%
from xgboost import XGBClassifier

# %%
xg = XGBClassifier(class_weight='balanced')
xg.fit(X_train_s, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               class_weight='balanced', colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, feature_weights=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None, ...)

# %%
test =

# %%
lr.predict(test)
# Out:
# array([0])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-17428897.py in <cell line: 0>()
# ----> 1 test.size
#
# AttributeError: 'list' object has no attribute 'size'

# %%
test = [[
       0.977438, 0.297915, -0.661028, 1.021690, 0.740218, -0.311576,
    0.091833, -0.076835, -0.710415, -0.298937, 0.685467, -0.561437,
    -0.375868, -1.085946, -1.400402, 0.229002, 0.058037, 0.520616,
    -1.317342, 0.078578, -0.049695, -0.637215, -0.114800, -1.392290,
    0.540989, 0.206059, 0.360926, 0.550727, 14773.52

]]

# %%
len(test)
# Out:
# 1

# %%
lr.predict(test)
# Out:
# array([0])

# %%
rt.predict(test)
# Out:
# array([1])

# %%
xg.predict(test)
# Out:
# array([1])

# %%
xg.feature_importances_
# Out:
# array([1.79703962e-02, 1.18008973e-02, 1.83698237e-02, 6.73696399e-02,
#        8.08330532e-03, 8.15415755e-03, 1.22680292e-02, 2.58061290e-02,
#        9.31273308e-03, 2.12715734e-02, 1.18529955e-02, 2.58475542e-02,
#        9.41096433e-03, 6.39135659e-01, 7.79569475e-03, 7.19735911e-03,
#        1.21167637e-02, 1.34514961e-02, 8.19575600e-03, 6.02210034e-03,
#        6.59961672e-03, 7.18586845e-03, 9.77571774e-03, 5.26191900e-03,
#        1.00482758e-02, 5.47740702e-03, 5.90627128e-03, 8.11293535e-03,
#        1.99016140e-04], dtype=float32)

# %%
import shap

# Create explainer
explainer = shap.TreeExplainer(xg)
shap_values = explainer.shap_values(test)  # X = your transaction(s)

# Plot for a single transaction
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values[0], test[0])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
import pickle as pkl

# %%
with open('Fraud_detection_xgb','wb') as f:
  pkl.dump(xg,f)
